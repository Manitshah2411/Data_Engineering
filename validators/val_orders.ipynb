# %%
import pandas as pd

df = pd.read_csv('../data/cleaned/orders.csv')
print(df.head())
# Out:
#                            order_id order_status order_purchase_timestamp  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered      2017-10-02 10:56:33
# 1  53cdb2fc8bc7dce0b6741e2150273451    delivered      2018-07-24 20:41:37
# 2  47770eb9100c2d0c44946d9cf07ec65d    delivered      2018-08-08 08:38:49
# 3  949d5b44dbf5de918fe9c16f97b45f8a    delivered      2017-11-18 19:28:06
# 4  ad21c59c0840e6cb83a9ceb5573f8159    delivered      2018-02-13 21:18:39
#
#      order_approved_at order_delivered_carrier_date  \
# 0  2017-10-02 11:07:15          2017-10-04 19:55:00
# 1  2018-07-26 03:24:27          2018-07-26 14:31:00
# 2  2018-08-08 08:55:23          2018-08-08 13:50:00
# 3  2017-11-18 19:45:59          2017-11-22 13:39:59
# 4  2018-02-13 22:20:29          2018-02-14 19:46:34
#
#   order_delivered_customer_date order_estimated_delivery_date  delayed_days  \
# 0           2017-10-10 21:25:13                    2017-10-18          -8.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_purchase_timestamp       99441 non-null  object
#  3   order_approved_at              99281 non-null  object
#  4   order_delivered_carrier_date   97658 non-null  object
#  5   order_delivered_customer_date  96476 non-null  object
#  6   order_estimated_delivery_date  99441 non-null  object
#  7   delayed_days                   99441 non-null  float64
#  8   order_completed                99441 non-null  bool
#  9   order_shipped                  99441 non-null  bool
#  10  order_approved                 99441 non-null  bool
#  11  order_total                    99441 non-null  float64
# ...

# %%
# order_id character varying(32) COLLATE pg_catalog."default" NOT NULL,
# customer_unique_id character varying(32) COLLATE pg_catalog."default" NOT NULL,
# order_status character varying(20) COLLATE pg_catalog."default" NOT NULL,
# order_purchase_timestamp timestamp without time zone NOT NULL,
# order_approved_at timestamp without time zone,
# order_delivered_customer_date timestamp without time zone,
# delayed_days integer,
# order_total numeric(14,2),
# total_freight numeric(14,2),
# num_items integer

"""
del df['order_delivered_carrier_date']
del df['order_estimated_delivery_date']
del df['order_completed']
del df['order_shipped']
del df['order_approved']
"""

# %%
cols = ['order_purchase_timestamp','order_approved_at','order_delivered_customer_date']

for col in cols:
    df[col] = pd.to_datetime(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   order_status                   99441 non-null  object
#  2   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  3   order_approved_at              99281 non-null  datetime64[ns]
#  4   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  5   delayed_days                   99441 non-null  float64
#  6   order_total                    99441 non-null  float64
#  7   total_freight                  99441 non-null  float64
#  8   num_items                      99441 non-null  float64
#  9   customer_unique_id             99441 non-null  object
# dtypes: datetime64[ns](3), float64(4), object(3)
# memory usage: 7.6+ MB

# %%
df.to_csv('../data/cleaned/orders.csv',index=False)

# %%
df['order_id'].drop_duplicates()
# Out:
# 0        e481f51cbdc54678b7cc49136f2d6af7
# 1        53cdb2fc8bc7dce0b6741e2150273451
# 2        47770eb9100c2d0c44946d9cf07ec65d
# 3        949d5b44dbf5de918fe9c16f97b45f8a
# 4        ad21c59c0840e6cb83a9ceb5573f8159
#                        ...
# 99436    9c5dedf39a927c1b2549525ed64a053c
# 99437    63943bddc261676b46f01ca7ac2f7bd8
# 99438    83c1379a015df1e13d02aae0204711ab
# 99439    11c177c8e97725db2631073c19f07b62
# 99440    66dea50a8b16d9b4dee7af250b4be1a5
# Name: order_id, Length: 99441, dtype: object

# %%
assert (df['order_total'] >= 0).all(), f"Error {df['order_id']}, {df['order_total']}"
assert (df['num_items'] >= 0).all(), f"Error"
assert (df['total_freight'] >= 0).all(), f"Error"
